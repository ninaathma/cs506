# %% [markdown]
# # Worksheet 19
#
# Name:  Nina Athma
# UID: U51803274
#
# ### Topics
#
# - Linear Model Evaluation
#
# ## Linear Model Evaluation
#
# Notice that R^2 only increases with the number of explanatory variables used. Hence the need for an adjusted R^2 that penalizes for insignificant explanatory variables.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

SAMPLE_SIZE = 100
beta = [1, 5]
X = -10.0 + 10.0 * np.random.random(SAMPLE_SIZE)
Y = beta[0] + beta[1] * X + np.random.randn(SAMPLE_SIZE)

for i in range(1, 15):
    X_transform = PolynomialFeatures(degree=i, include_bias=False).fit_transform(X.reshape(-1, 1))
    model = LinearRegression()
    model.fit(X_transform, Y)
    print(model.score(X_transform, Y))
# Out:
# 0.9956569052732728
# 0.9956730453187084
# 0.9957142801131601
# 0.9957403902602018
# 0.9958984194488464
# 0.9959075620814493
# 0.9959186951898429
# 0.995920421775577
# 0.9961517407081123
# 0.9961710893918987
# 0.99617398710961
# 0.9961758102447454
# 0.9962081407588514
# 0.996227980845679

# %% [markdown]
# a) Hypothesis Testing Sandbox (follow along in class) [Notes](https://medium.com/@gallettilance/hypothesis-testing-almost-everything-you-need-to-know-ce812ded50b)

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

flips = [1, 0, 0, 1, 0]

def num_successes(flips):
    return sum(flips)

print(binom.pmf(num_successes(flips), len(flips), 1/2))

SAMPLE_SIZE = 5
flips = [np.random.choice([0, 1]) for _ in range(SAMPLE_SIZE)]
print(flips)
print(binom.pmf(num_successes(flips), SAMPLE_SIZE, 1/2))

p_est = []

for _ in range(1000):
    flips = [np.random.choice([0, 1]) for _ in range(SAMPLE_SIZE)]
    p_est.append(sum(flips) / SAMPLE_SIZE)

fig, ax = plt.subplots()
_, bins, patches = ax.hist(p_est, bins=SAMPLE_SIZE + 1)
p = np.digitize([2/5], bins)
patches[p[0]-1].set_facecolor('r')
ax.bar_label(patches)
plt.show()
# Out:
# 0.31249999999999983
# [0, 0, 0, 0, 1]
# 0.15624999999999997

# %% [markdown]
# b) Plot a data set and fitted line through the point when there is no relationship between X and y.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 10

xlin = -1.0 + 1.0 * np.random.random(SAMPLE_SIZE)
y = np.random.randn(SAMPLE_SIZE)

intercept = np.ones(np.shape(xlin)[0])
X = np.array([intercept, xlin]).T
beta = np.zeros(X.shape[1]) # Set coefficients to zero

xplot = xlin
yestplot = np.dot(X, beta)  # Fitted line when coefficients are zero
plt.plot(xplot, yestplot,'b-',lw=2)
plt.plot(xlin, y,'ro',markersize=4)
plt.show()

# %% [markdown]
# c) Using the above code, plot a histogram of the parameter estimates for the slope after generating `1000` independent datasets. Comment on what the plot means. Increase the sample size to see what happens to the plot. Explain.

# %%
# Function to calculate the slope parameter estimate
def calculate_slope_estimate(x, y):
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x]).T
    beta = np.linalg.inv(X.T @ X) @ X.T @ y
    return beta[1]


beta_hist = []
for _ in range(1000):
    xlin = -1.0 + 1.0 * np.random.random(10)
    y = np.random.randn(10)
    slope_estimate = calculate_slope_estimate(xlin, y)
    beta_hist.append(slope_estimate)

fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True, color='blue', alpha=0.7)
plt.xlabel('Slope Parameter Estimate')
plt.ylabel('Density')
plt.title('Histogram of Slope Parameter Estimates')
plt.show()

# %% [markdown]
# The histogram provides an empirical distribution of the estimated slope parameter across the 1000 datasets. The shape of the histogram gives insights into the variability and uncertainty associated with estimating the slope in datasets of size 10. The spread of the histogram indicates how much the estimated slope can vary across different random datasets of the same size.
#
# If you increase the sample size, you might observe a narrower distribution with less variability in the estimated slope. Larger sample sizes tend to provide more precise parameter estimates, reducing the impact of random fluctuations in the data.The histogram would be expected to approach a normal distribution as the sample size increases due to the Central Limit Theorem.

# %% [markdown]
# d) We know that:
#
# $$\hat\beta-\beta \sim \mathcal{N}(0,\sigma^2 (X^TX)^{-1})$$
#
# thus for each component $k$ of $\hat\beta$ (here there are only two - one slope and one intercept)
#
# $$\hat\beta_k -\beta_k \sim \mathcal{N}(0, \sigma^2 S_{kk})$$
#
# where $S_{kk}$ is the $k^\text{th}$ diagonal element of $(X^TX)^{-1}$. Thus, we know that
#
# $$z_k = \frac{\hat\beta_k -\beta_k}{\sqrt{\sigma^2 S_{kk}}} \sim \mathcal{N}(0,1)$$
#
# Verify that this is the case through a simulation and compare it to the standard normal pdf by plotting it on top of the histogram.

# %%
from scipy.stats import norm

beta_hist = []
for _ in range(1000):
    xlin = -1.0 + 1.0 * np.random.random(SAMPLE_SIZE)
    y = np.random.randn(SAMPLE_SIZE)
    slope_estimate = calculate_slope_estimate(xlin, y)
    beta_hist.append(slope_estimate)

xs = np.linspace(-10,10,1000)
fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True)
ax.plot(xs, norm.pdf(xs), color='green',label='Standard Normal PDF')
plt.show()

# %% [markdown]
# e) Above we normalized $\hat\beta$ by subtracting the mean and dividing by the standard deviation. While we know that the estimate of beta is an unbiased estimator, we don't know the standard deviation. So in practice when doing a hypothesis test where we want to assume that $\beta = 0$, we can simply use $\hat\beta$ in the numerator. However we don't know the standard deviation and need to use an unbiased estimate of the standard deviation instead. This estimate is the standard error `s`
#
# $$s = \sqrt{\frac{RSS}{n - p}}$$
#
# where p is the number of parameters beta (here there are 2 - one slope and one intercept). This normalized $\hat\beta$ can be shown to follow a t-distribution with `n-p` degrees of freedom. Verify this is the case with a simulation.

# %%
from scipy.stats import t

def standard_error(ytrue, ypred):
    residuals = ytrue - ypred
    return np.sqrt(np.sum(residuals**2) / (len(ytrue) - len(ypred)))

beta_hist = []
for _ in range(1000):
    xlin = -1.0 + 1.0 * np.random.random(SAMPLE_SIZE)
    y = np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(xlin)[0])
    X = np.array([intercept, xlin]).T
    beta = np.linalg.inv(X.T @ X) @ X.T @ y
    ypred = X @ beta
    se = standard_error(y, ypred)
    normalized_beta = beta[1] / se
    beta_hist.append(normalized_beta)

xs = np.linspace(-10,10,1000)
fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True)
ax.plot(xs, t.pdf(xs, SAMPLE_SIZE - 2), color='red')
plt.xlabel('Normalized beta')
plt.ylabel('Density')
plt.title('Comparison of Simulated Normalized beta and t-Distribution PDF')
plt.legend()
plt.show()
# Out:
# /var/folders/nl/fmfw3x8n5rs7wrk_bvkrkm6c0000gn/T/ipykernel_3636/1709060861.py:5: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(np.sum(residuals**2) / (len(ytrue) - len(ypred)))
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# f) You are given the following dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([-0.1920605, -0.11290798, -0.56434374, -0.67052057, -0.19233284, -0.42403586, -0.8114285, -0.38986946, -0.37384161, -0.50930229])
y = np.array([-0.34063108, -0.33409286, 0.34245857, 0.11062295, 0.76682389, 0.86592388, -1.68912015, -2.01463592, 1.61798563, 0.60557414])

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

print(beta_hat)

xplot = np.linspace(-1,.25,20)
yestplot = beta_hat[0] + beta_hat[1] * xplot
plt.plot(xplot, yestplot,'b-',lw=2)
plt.plot(x, y,'ro',markersize=4)
plt.show()
# Out:
# [0.50155603 1.19902827]

# %% [markdown]
# what is the probability of observing a dataset at least as extreme as the above assuming $\beta = 0$ ?

# %%
residuals = y - X @ beta_hat

# Standard error of the estimate
se = np.sqrt(np.sum(residuals**2) / (len(y) - len(beta_hat)))

# t-statistic
t_statistic = beta_hat[1] / se

# Degrees of freedom
df = len(y) - len(beta_hat)

# Two-tailed p-value
p_value = 2 * (1 - t.cdf(np.abs(t_statistic), df))

print(f"t-statistic: {t_statistic}")
print(f"Degrees of freedom: {df}")
print(f"P-value: {p_value}")
# Out:
# t-statistic: 1.0248600743927672
# Degrees of freedom: 8
# P-value: 0.335417218459404

# %% [markdown]
# The probability of observing a dataset at least as extreme as the given one is 0.335417.
