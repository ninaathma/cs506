# %% [markdown]
# # Worksheet 24
#
# Name:  Nina Athma
# UID: U51803274
#
# ### Topics
#
# - Tuning Neural Networks
#
# ## Tuning Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (4.25.1)
# Requirement already satisfied: setuptools in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (6.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Nina/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# WARNING: There was an error checking the latest version of pip.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(3, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

X, Y = generate_curve_data(t)

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=50, epochs=200)

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# 2023-12-06 22:12:44.662681: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 3/3 [==============================] - 1s 8ms/step - loss: 0.7787
# Epoch 2/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7750
# Epoch 3/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7725
# Epoch 4/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7704
# Epoch 5/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7685
# Epoch 6/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7667
# Epoch 7/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7650
# Epoch 8/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7635
# Epoch 9/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7619
# Epoch 10/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7604
# Epoch 11/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7588
# Epoch 12/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7575
# Epoch 13/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7560
# Epoch 14/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7547
# Epoch 15/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7535
# Epoch 16/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7522
# Epoch 17/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7509
# Epoch 18/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.7496
# Epoch 19/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7482
# Epoch 20/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7470
# Epoch 21/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7457
# Epoch 22/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7445
# Epoch 23/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7433
# Epoch 24/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7422
# Epoch 25/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7409
# Epoch 26/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7398
# Epoch 27/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7386
# Epoch 28/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7374
# Epoch 29/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7362
# Epoch 30/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7351
# Epoch 31/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7340
# Epoch 32/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7330
# Epoch 33/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7320
# Epoch 34/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7310
# Epoch 35/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7299
# Epoch 36/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7289
# Epoch 37/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7279
# Epoch 38/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7269
# Epoch 39/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7260
# Epoch 40/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7250
# Epoch 41/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7240
# Epoch 42/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7230
# Epoch 43/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7221
# Epoch 44/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7212
# Epoch 45/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7203
# Epoch 46/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7194
# Epoch 47/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7184
# Epoch 48/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7176
# Epoch 49/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7167
# Epoch 50/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7158
# Epoch 51/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7151
# Epoch 52/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7142
# Epoch 53/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7135
# Epoch 54/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7127
# Epoch 55/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7120
# Epoch 56/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7112
# Epoch 57/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7105
# Epoch 58/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7098
# Epoch 59/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7091
# Epoch 60/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7083
# Epoch 61/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7077
# Epoch 62/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7069
# Epoch 63/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7063
# Epoch 64/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7056
# Epoch 65/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7049
# Epoch 66/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7043
# Epoch 67/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7036
# Epoch 68/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7030
# Epoch 69/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7023
# Epoch 70/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7017
# Epoch 71/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7012
# Epoch 72/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7006
# Epoch 73/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7000
# Epoch 74/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6993
# Epoch 75/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6987
# Epoch 76/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6982
# Epoch 77/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6976
# Epoch 78/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6971
# Epoch 79/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6965
# Epoch 80/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6960
# Epoch 81/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6954
# Epoch 82/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6948
# Epoch 83/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6943
# Epoch 84/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6937
# Epoch 85/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6932
# Epoch 86/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6926
# Epoch 87/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6921
# Epoch 88/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6916
# Epoch 89/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6911
# Epoch 90/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6906
# Epoch 91/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6900
# Epoch 92/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6896
# Epoch 93/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6891
# Epoch 94/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6886
# Epoch 95/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6882
# Epoch 96/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6877
# Epoch 97/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6872
# Epoch 98/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6868
# Epoch 99/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6863
# Epoch 100/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6858
# Epoch 101/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6854
# Epoch 102/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6849
# Epoch 103/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6845
# Epoch 104/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6841
# Epoch 105/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6837
# Epoch 106/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6833
# Epoch 107/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6829
# Epoch 108/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6824
# Epoch 109/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6819
# Epoch 110/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6815
# Epoch 111/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6811
# Epoch 112/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6807
# Epoch 113/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6802
# Epoch 114/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6798
# Epoch 115/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6794
# Epoch 116/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6790
# Epoch 117/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6785
# Epoch 118/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6781
# Epoch 119/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6778
# Epoch 120/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6774
# Epoch 121/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6770
# Epoch 122/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6765
# Epoch 123/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6761
# Epoch 124/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6758
# Epoch 125/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6753
# Epoch 126/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6749
# Epoch 127/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6746
# Epoch 128/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6741
# Epoch 129/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6737
# Epoch 130/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6733
# Epoch 131/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6728
# Epoch 132/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6724
# Epoch 133/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6721
# Epoch 134/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6716
# Epoch 135/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6712
# Epoch 136/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6708
# Epoch 137/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6703
# Epoch 138/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6699
# Epoch 139/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6695
# Epoch 140/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6692
# Epoch 141/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6689
# Epoch 142/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6683
# Epoch 143/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6680
# Epoch 144/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6675
# Epoch 145/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6672
# Epoch 146/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6667
# Epoch 147/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6663
# Epoch 148/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6659
# Epoch 149/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6656
# Epoch 150/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6651
# Epoch 151/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6647
# Epoch 152/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.6643
# Epoch 153/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6639
# Epoch 154/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6634
# Epoch 155/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6630
# Epoch 156/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6625
# Epoch 157/200
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6621
# Epoch 158/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6617
# Epoch 159/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6612
# Epoch 160/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6609
# Epoch 161/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6603
# Epoch 162/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6600
# Epoch 163/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6595
# Epoch 164/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6591
# Epoch 165/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6586
# Epoch 166/200
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6582
# Epoch 167/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6578
# Epoch 168/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6573
# Epoch 169/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6568
# Epoch 170/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6565
# Epoch 171/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6560
# Epoch 172/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6556
# Epoch 173/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6551
# Epoch 174/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6546
# Epoch 175/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6542
# Epoch 176/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6537
# Epoch 177/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6532
# Epoch 178/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6527
# Epoch 179/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6522
# Epoch 180/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6517
# Epoch 181/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6512
# Epoch 182/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6508
# Epoch 183/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6502
# Epoch 184/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6498
# Epoch 185/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6492
# Epoch 186/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6487
# Epoch 187/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6482
# Epoch 188/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6477
# Epoch 189/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6471
# Epoch 190/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6467
# Epoch 191/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6461
# Epoch 192/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6456
# Epoch 193/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6450
# Epoch 194/200
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6445
# Epoch 195/200
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6440
# Epoch 196/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6435
# Epoch 197/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6429
# Epoch 198/200
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6423
# Epoch 199/200
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6418
# Epoch 200/200
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6412
# 3602/3602 [==============================] - 6s 2ms/step
